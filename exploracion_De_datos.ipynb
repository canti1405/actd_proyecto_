# %%
from openpyxl import load_workbook
import pandas as pd

# Cargar el libro de Excel sin leer los datos todavía
excel_path = "datos_utiles.xlsx"
workbook = load_workbook(excel_path, read_only=True)

# Mostrar los nombres de las hojas disponibles
sheet_names = workbook.sheetnames
sheet_names
df = pd.read_excel(excel_path, sheet_name="Sheet1")

# %%
# Generar estadísticas descriptivas
desc_stats = df.describe().T
desc_stats
# Out:
#                          count          mean        std      min      25%  \
# periodo               561287.0  20171.976807   0.150517  20171.0  20172.0
# edad                  561287.0     16.492931   5.816094    -58.0     16.0
# fami_estratovivienda  561287.0      2.081946   1.028364      1.0      1.0
# fami_tieneautomovil   561287.0      0.227630   0.419303      0.0      0.0
# fami_tienecomputador  561287.0      0.605665   0.488708      0.0      0.0
# fami_tieneinternet    561287.0      0.597771   0.490348      0.0      0.0
# fami_tienelavadora    561287.0      0.747653   0.434360      0.0      0.0
# punt_global           561287.0    256.567998  49.409496      0.0    219.0
# cole_bilingue         561287.0      0.000000   0.000000      0.0      0.0
# es_elegible_beca      561287.0      0.035876   0.185982      0.0      0.0
#
#                           50%      75%      max
# periodo               20172.0  20172.0  20172.0
# edad                     16.0     17.0     42.0
# ...

# %% [markdown]
# ### Histogramas

# %%
import matplotlib.pyplot as plt

# Histogramas de variables relevantes
variables = ['edad', 'fami_estratovivienda', 'punt_global']

for col in variables:
    plt.figure(figsize=(6,4))
    df[col].hist(bins=30, edgecolor='black')
    plt.title(f'Histograma de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

# Boxplot: puntaje global por estrato
plt.figure(figsize=(8,5))
sns.boxplot(x='fami_estratovivienda', y='punt_global', data=df)
plt.title('Boxplot de Puntaje Global por Estrato')
plt.xlabel('Estrato')
plt.ylabel('Puntaje Global')
plt.tight_layout()
plt.show()

# %%
# Dispersión entre edad y puntaje global
plt.figure(figsize=(7,5))
sns.scatterplot(x='edad', y='punt_global', data=df, alpha=0.5)
plt.title('Dispersión entre Edad y Puntaje Global')
plt.xlabel('Edad')
plt.ylabel('Puntaje Global')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Diagrama de violín para comparar puntaje global según si tiene computador
plt.figure(figsize=(8,5))
sns.violinplot(x='fami_tienecomputador', y='punt_global', data=df)
plt.title('Diagrama de Violín: Puntaje Global según Tenencia de Computador')
plt.xlabel('Tiene Computador (0 = No, 1 = Sí)')
plt.ylabel('Puntaje Global')
plt.tight_layout()
plt.show()
